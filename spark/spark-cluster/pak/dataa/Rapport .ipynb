# %%
import pandas as pd
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("pyspark-notebook").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "1g").\
        getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from pyspark.sql import SparkSession
#       4 #sans se connecter au cluster
#       5 #spark = SparkSession.builder.getOrCreate()
#       7 spark = SparkSession.\
#       8         builder.\
#       9         appName("pyspark-notebook").\
#      10         master("spark://spark-master:7077").\
#      11         config("spark.executor.memory", "1g").\
#      12         getOrCreate()
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
ls
# Out:
#  Le volume dans le lecteur C n’a pas de nom.
#  Le numéro de série du volume est E41A-45AF
#
#  Répertoire de C:\Users\amine\Desktop\fichier csv
#
# 03/11/2022  11:47    <DIR>          .
# 03/11/2022  11:47    <DIR>          ..
# 03/11/2022  11:47    <DIR>          .ipynb_checkpoints
# 03/11/2022  10:24    <DIR>          accident de la route
# 03/11/2022  10:25    <DIR>          circulation
# 03/11/2022  10:23    <DIR>          pollution air
# 03/11/2022  11:47                72 Untitled.ipynb
#                1 fichier(s)               72 octets
#                6 Rép(s)  374 920 122 368 octets libres

# %%
df = pd.read_csv("circulation/observatoire-parisien-des-mobilites-barometre-trimestriel-des-deplacements.csv",sep=";")

# %%
df[df["Indice fréquentation vélo"]>2.50]
# Out:
#     Année Trimestre Numéro trimestre Début trimestre Fin trimestre  \
# 0    2016   2016 T1               T1      2016-01-01    2016-03-31
# 1    2017   2017 T1               T1      2017-01-01    2017-03-31
# 2    2018   2018 T4               T4      2018-10-01    2018-12-31
# 3    2019   2019 T1               T1      2019-01-01    2019-03-31
# 4    2019   2019 T2               T2      2019-04-01    2019-06-30
# 5    2020   2020 T1               T1      2020-01-01    2020-03-31
# 8    2013   2013 T2               T2      2013-04-01    2013-06-30
# 9    2013   2013 T3               T3      2013-07-01    2013-09-30
# 10   2016   2016 T2               T2      2016-04-01    2016-06-30
# 11   2020   2020 T2               T2      2020-04-01    2020-06-30
# 12   2020   2020 T4               T4      2020-10-01    2020-12-31
# 14   2021   2021 T2               T2      2021-04-01    2021-06-30
# 16   2017   2017 T3               T3      2017-07-01    2017-09-30
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from pyspark.sql import SparkSession
#       3 #sans se connecter au cluster
#       4 #spark = SparkSession.builder.getOrCreate()
#       6 spark = SparkSession.\
#       7         builder.\
#       8         appName("pyspark-notebook").\
#       9         master("spark://spark-master:7077").\
#      10         config("spark.executor.memory", "1g").\
#      11         getOrCreate()
#
# ModuleNotFoundError: No module named 'pyspark'
